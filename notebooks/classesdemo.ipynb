# %%
import geopandas as gpd 
path = 'C:/Users/User/Desktop/TCC/TCC/random_points.shp'
type(gpd.read_file(path))
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
from interp import Interpolador

interpolacao = Interpolador(caminho='C:/Users/User/Desktop/TCC/TCC/random_points.shp', coluna_z="Elevation", resolucao_espacial=80, algoritmo="Vizinhos")

dados_interpolados = interpolacao.interpolar()

interpolacao.plotagem_matplotlib(dados_interpolados, "PRGn")
# Out:
# Iniciando interpolação
# Iniciando remodelação - criando objetos
# obtendo shape..
# reshape..
# Iniciando plot

# %%
import geopandas as gpd

pontos = gpd.read_file('C:/Users/User/Desktop/TCC/TCC/random_points.shp')
pontos
# Out:
#        id  Elevation                        geometry
# 0    None       1496  POINT (342975.047 7590757.461)
# 1    None       1630  POINT (341928.689 7591631.849)
# 2    None       1621  POINT (340291.331 7591627.004)
# 3    None       1567  POINT (339710.021 7591375.103)
# 4    None       1516  POINT (338968.850 7591849.840)
# ..    ...        ...                             ...
# 249  None       1446  POINT (343290.037 7589350.035)
# 250  None       1495  POINT (343357.857 7589786.018)
# 251  None       1552  POINT (343435.365 7590018.542)
# 252  None       1563  POINT (343202.841 7590086.362)
# 253  None       1417  POINT (343009.070 7589543.805)
#
# [254 rows x 3 columns]
